# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
deliveries=pd.read_csv(r"C:\Users\dines\Downloads\deliveries.csv")
matches=pd.read_csv(r"C:\Users\dines\Downloads\matches.csv")

# %%
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
deliveries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
matches.groupby('city')['season'].count()
# Out:
# city
# Abu Dhabi           7
# Ahmedabad          12
# Bangalore          66
# Bengaluru          14
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         46
# Chennai            57
# Cuttack             7
# Delhi              74
# Dharamsala          9
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            77
# Mohali             10
# Mumbai            101
# Nagpur              3
# Port Elizabeth      7
# Pune               38
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah             6
# Visakhapatnam      13
# Name: season, dtype: int64

# %%
matches
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
deliveries
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
matches.season.value_counts()
# Out:
# 2013    76
# 2012    74
# 2011    73
# 2010    60
# 2014    60
# 2016    60
# 2018    60
# 2019    60
# 2017    59
# 2015    59
# 2008    58
# 2009    57
# Name: season, dtype: int64

# %%
matches.toss_decision.value_counts()
# Out:
# field    463
# bat      293
# Name: toss_decision, dtype: int64

# %%
batting_second_wins = matches[(matches['toss_decision'] == 'field') & (matches['team2'] == matches['winner'])]
batting_second_wins_by_year = batting_second_wins['season'].value_counts()
years_with_most_wins = batting_second_wins_by_year[batting_second_wins_by_year == batting_second_wins_by_year.max()].index

print("Years where taking batting second has won more matches:")
print(years_with_most_wins)
# Out:
# Years where taking batting second has won more matches:
# Int64Index([2016], dtype='int64')

# %%
new=deliveries[deliveries.batsman=='RA Jadeja']
new[deliveries.dismissal_kind=="caught and bowled"]
# Out:
# C:\Users\dines\AppData\Local\Temp\ipykernel_16396\3794344989.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   new[deliveries.dismissal_kind=="caught and bowled"]
#         match_id  inning          batting_team                 bowling_team  \
# 6202          26       2         Gujarat Lions              Kings XI Punjab
# 7930          34       1         Gujarat Lions               Mumbai Indians
# 61715        261       1  Kochi Tuskers Kerala             Rajasthan Royals
# 107197       452       2   Chennai Super Kings  Royal Challengers Bangalore
# 146736       620       2         Gujarat Lions  Royal Challengers Bangalore
#
#         over  ball    batsman  non_striker       bowler  is_super_over  ...  \
# 6202      12     6  RA Jadeja   KD Karthik  KC Cariappa              0  ...
# 7930      14     5  RA Jadeja  JP Faulkner    KH Pandya              0  ...
# 61715     16     3  RA Jadeja     PA Patel     SK Warne              0  ...
# ...

# %%
vk=deliveries[(deliveries.batsman=='V Kohli') & (deliveries.bowler== 'JJ Bumrah')]

# %%
vk.batsman_runs.sum()
# Out:
# 112

# %%
matches.venue.value_counts()
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %%
deliveries[(deliveries.player_dismissed=='V Kohli') & (deliveries.dismissal_kind=='run out')]
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 44313        188       2  Royal Challengers Bangalore       Mumbai Indians
# 86607        367       1  Royal Challengers Bangalore       Mumbai Indians
# 97327        411       1  Royal Challengers Bangalore        Pune Warriors
# 103835       438       1  Royal Challengers Bangalore     Delhi Daredevils
# 117242       495       1  Royal Challengers Bangalore     Delhi Daredevils
# 131387       554       2  Royal Challengers Bangalore  Chennai Super Kings
#
#         over  ball     batsman     non_striker       bowler  is_super_over  \
# 44313     17     6     V Kohli       JH Kallis       Z Khan              0
# 86607      3     4  TM Dilshan         V Kohli     MM Patel              0
# 97327     17     2     V Kohli        CH Gayle     AB Dinda              0
# 103835    20     6     V Kohli  AB de Villiers     UT Yadav              0
# ...

# %%
deliveries[deliveries.bowler=='P Kumar'].extra_runs.sum()
# Out:
# 236

# %%
deliveries[deliveries.bowler=='SR Watson'].extra_runs.sum()
# Out:
# 171

# %%
deliveries[deliveries.bowler=='SL Malinga'].extra_runs.sum()
# Out:
# 293

# %%
deliveries[(deliveries.batsman=='V Kohli') ]
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...          ...     ...                          ...                  ...
# 177522     11345       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 177523     11345       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 177524     11345       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 177525     11345       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 177527     11345       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
deliveries.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
deliveries.dismissal_kind.unique()
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'caught and bowled',
#        'stumped', 'retired hurt', 'hit wicket', 'obstructing the field'],
#       dtype=object)

# %%
a=deliveries[(deliveries.dismissal_kind =='caught') |(deliveries.dismissal_kind =='bowled') | 
          (deliveries.dismissal_kind =='lbw') | (deliveries.dismissal_kind =='caught and bowled') |
          (deliveries.dismissal_kind =='stumped') | (deliveries.dismissal_kind =='hit wicket')]

# %%
a[a.bowler=='A Mishra']
# Out:
#         match_id  inning            batting_team      bowling_team  over  \
# 2089           9       2  Rising Pune Supergiant  Delhi Daredevils    12
# 2096           9       2  Rising Pune Supergiant  Delhi Daredevils    14
# 2111           9       2  Rising Pune Supergiant  Delhi Daredevils    16
# 3508          15       2         Kings XI Punjab  Delhi Daredevils    11
# 4308          18       2   Kolkata Knight Riders  Delhi Daredevils    20
# ...          ...     ...                     ...               ...   ...
# 177237     11344       1        Rajasthan Royals    Delhi Capitals    12
# 177238     11344       1        Rajasthan Royals    Delhi Capitals    12
# 177249     11344       1        Rajasthan Royals    Delhi Capitals    14
# 178377     11413       1     Sunrisers Hyderabad    Delhi Capitals     7
# 178789     11414       2     Chennai Super Kings    Delhi Capitals    13
#
#         ball     batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# ...

# %%
x=deliveries[(deliveries.batsman_runs==6) | (deliveries.batsman_runs==4) ]

# %%
x.groupby('batsman')['batsman_runs'].sum()[x.groupby('batsman')['batsman_runs'].sum()==3466]
# Out:
# batsman
# CH Gayle    3466
# Name: batsman_runs, dtype: int64

# %%
matches[(matches.season==2017) & ((matches.team1=='Royal Challengers Bangalore') | (matches.team2=='Royal Challengers Bangalore'))]
# Out:
#     id  season       city        date                        team1  \
# 0    1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 4    5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 7    8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 11  12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 16  17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 19  20    2017     Rajkot  2017-04-18  Royal Challengers Bangalore
# 26  27    2017    Kolkata  2017-04-23        Kolkata Knight Riders
# 29  30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
# 32  33    2017       Pune  2017-04-29       Rising Pune Supergiant
# 36  37    2017     Mumbai  2017-05-01  Royal Challengers Bangalore
# 41  42    2017  Bangalore  2017-05-05              Kings XI Punjab
# 44  45    2017  Bangalore  2017-05-07  Royal Challengers Bangalore
# 54  55    2017      Delhi  2017-05-14  Royal Challengers Bangalore
#
# ...

# %%
merged = pd.merge(matches, deliveries, left_on='id', right_on='match_id')

# %%
merged
# Out:
#            id  season       city        date                team1  \
# 0           1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1           1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 2           1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 3           1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 4           1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# ...       ...     ...        ...         ...                  ...
# 179073  11415    2019  Hyderabad    12/05/19       Mumbai Indians
# 179074  11415    2019  Hyderabad    12/05/19       Mumbai Indians
# 179075  11415    2019  Hyderabad    12/05/19       Mumbai Indians
# 179076  11415    2019  Hyderabad    12/05/19       Mumbai Indians
# 179077  11415    2019  Hyderabad    12/05/19       Mumbai Indians
#
#                               team2                  toss_winner  \
# 0       Royal Challengers Bangalore  Royal Challengers Bangalore
# ...

# %%
vk=merged[(merged.season==2016) & (merged.batsman=='V Kohli')]

# %%
vk.batsman_runs.count()
# Out:
# 655

# %%
973/655
# Out:
# 1.4854961832061069

# %%
matches
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
batsecond=matches[((matches.toss_decision=='field') & (matches.toss_winner==matches.winner)) | 
       ((matches.toss_decision=='bat') & (matches.toss_winner!=matches.winner))]

# %%
batsecond
# Out:
#         id  season           city        date                   team1  \
# 1        2    2017           Pune  2017-04-06          Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07           Gujarat Lions
# 3        4    2017         Indore  2017-04-08  Rising Pune Supergiant
# 5        6    2017      Hyderabad  2017-04-09           Gujarat Lions
# 6        7    2017         Mumbai  2017-04-09   Kolkata Knight Riders
# ..     ...     ...            ...         ...                     ...
# 750  11346    2019         Mohali    05/05/19     Chennai Super Kings
# 751  11347    2019         Mumbai    05/05/19   Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19     Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19     Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19          Delhi Capitals
#
#                       team2             toss_winner toss_decision  result  \
# ...

# %%
batsecond.season.value_counts()
# Out:
# 2011    41
# 2016    41
# 2012    40
# 2013    39
# 2014    37
# 2008    36
# 2019    36
# 2017    33
# 2018    32
# 2009    30
# 2010    28
# 2015    25
# Name: season, dtype: int64
